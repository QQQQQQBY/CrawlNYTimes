# %%
import pandas as pd

# %%
data = pd.read_csv("leadstories-leadstories.csv")

# %%
data.sample(10)
# Out:
#                                                     url  \
# 1126  https://leadstories.com/hoax-alert/2022/07/fac...
# 2044  https://leadstories.com/hoax-alert/2021/12/fac...
# 2581  https://leadstories.com/hoax-alert/2021/07/fac...
# 2536  https://leadstories.com/hoax-alert/2021/08/fac...
# 1987  https://leadstories.com/hoax-alert/2021/12/fac...
# 2272  https://leadstories.com/hoax-alert/2021/10/fac...
# 1020  https://leadstories.com/hoax-alert/2022/07/fac...
# 966   https://leadstories.com/hoax-alert/2022/08/fac...
# 766   https://leadstories.com/hoax-alert/2022/09/fac...
# 771   https://leadstories.com/hoax-alert/2022/09/fac...
#
#                                                   title  \
# 1126  Fact Check: Apple Logo Is NOT Honoring Invento...
# 2044  Fact Check: Eating Cashews Does NOT Kill Bacteria
# 2581  Fact Check: New Washington State Reforms Would...
# 2536  Fact Check: All Spirit Airlines Flight Attenda...
# 1987  Fact Check: Prime Minister of New Zealand Did ...
# ...

# %%
s = data.sample(10)

# %%
s.iloc[2].url
# Out:
# 'https://leadstories.com/hoax-alert/2022/04/fact-check-video-does-not-show-moon-at-the-border-of-russia-and-canada-at-the-north-pole-its-computer-generated-art.html'

# %%
s.iloc[0].url
# Out:
# 'https://leadstories.com/hoax-alert/2023/02/fact-check-Thailand-does-not-plan-to-nullify-Pfizer-BioNTech-contracts.html'

# %%
s
# Out:
#                                                     url  \
# 63    https://leadstories.com/hoax-alert/2023/02/fac...
# 2271  https://leadstories.com/hoax-alert/2021/10/fac...
# 1389  https://leadstories.com/hoax-alert/2022/04/fac...
# 2423  https://leadstories.com/hoax-alert/2021/08/wer...
# 2355  https://leadstories.com/hoax-alert/2021/09/fac...
# 636   https://leadstories.com/hoax-alert/2022/10/fac...
# 1381  https://leadstories.com/hoax-alert/2022/05/fac...
# 1118  https://leadstories.com/hoax-alert/2022/07/fac...
# 2064  https://leadstories.com/analysis/2021/11/who-i...
# 2269  https://leadstories.com/hoax-alert/2021/10/fac...
#
#                                                   title  \
# 63    Fact Check: Thailand Does NOT Plan To 'Nullify...
# 2271  Fact Check: People Are NOT Exempt From Carryin...
# 1389  Fact Check: Video Does NOT Show 'Moon At The B...
# 2423  Fact Check: Werner Herzog Did NOT Say America ...
# 2355  Fact Check: Biden Does NOT Have A Body Double ...
# ...
